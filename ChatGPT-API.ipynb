# %%
# %%capture
# update the OpenAI Python library to make sure you are using the latest version
# !pip install --upgrade openai
# !pip install python-dotenv

# %%
import openai
import os
import IPython
from dotenv import load_dotenv
load_dotenv()
from openai import OpenAI

client = OpenAI(api_key = "sk-proj-ruxakYkyuYYVhuof2E7nT3BlbkFJzb1WjbPJvKaEsxlEEYXH")

# %% [markdown]
# # Basic API Calls

# %%
response = client.chat.completions.create(
    model= "babbage-002",
     messages=[
        {"role": "system", "content": "You are an AI Assistant for a Tech Company. You use a tone that is technical and scientific."},
        {"role": "user", "content": "Hello, who are you?"},
        {"role": "assistant", "content": "Greeting! I am an Kaze. How may I help you today?"},
        {"role": "user", "content": "Can you tell me about .yaml files?"}
    ],
    temperature=0,
)


print(response.choices[0].text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 response.choices[0].message.content
#
# NameError: name 'response' is not defined

# %%
response.choices[0].message.content

# %%
IPython.display.Markdown(response.choices[0].message.content)

# %% [markdown]
# # Non-Conversation Request

# %%
CONTENT = """Answer the question based on the context below. Keep the answer short and concise. Respond \"Unsure about answer\" if not sure about the answer.

Context: Provide an analysis of the impact of social media on political polarization in democratic societies. Include statistical data and case studies to support your arguments, and discuss both the positive and negative effects. Conclude with potential solutions to mitigate the negative impacts while enhancing the positive ones.

Question: What How does social media usage influence the mental health of teenagers, and what strategies can be implemented to maximize the benefits while minimizing the drawbacks? Provide evidence from recent studies to support your analysis.?

Answer:
"""

response = openai.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "user", "content": CONTENT},
    ],
    temperature=0,
)

print(response.choices[0].message.content)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=28965bad-6848-4837-be43-7629856e4984' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
